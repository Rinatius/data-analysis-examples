# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('data/Minjust2018.csv', 
                 header=None, 
                 usecols=[4, 27, 28, 33])
df.fillna('', inplace=True)
df.rename(columns={4: 'name', 
                   27: 'director', 
                   28: 'activity', 
                   33: 'founders'},
              inplace = True)

# %%
pattern = re.compile(r'(\A|\s)[ауоыиэюяеёй]{2,}($|\s)',re.IGNORECASE)
df.loc[df['director'].str.contains(pattern)]
# Out:
# /home/rinat/miniconda3/envs/excel/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#                                                      name  \
# 349                     Кыргызско-Китайское ОсОО "Залив "
# 1867    ООО  Иностранное  китайское  "КОМПАНИЯ  ЗОЛОТО...
# 2074     Совместное Кыргызско-Китайское предприятие "ФДК"
# 2528    Общественное объединение "Центр гендерных иссл...
# 3713    Общество с ограниченной ответственностью «Кита...
# 5695    Общество с ограниченной ответственностью "DT M...
# 6327    Общество с ограниченной ответственностью "DaDe...
# 7385    Общество с ограниченной ответственностью "ГДК ...
# 9571    Общество с ограниченной ответственностью «ДАФУ...
# 10641   Общество с ограниченной ответственностью "Кен ...
# 11844    Общество с ограниченной ответственностью «Тай К»
# 16756              ОсОО "MCDONALD" (Магдоналд) (ИУ-Китай)
# 17359   Общество с ограниченной ответственностью "WUL"...
# 20245                             ОсОО "ЛАБЕЛЛА" (ИУ-КНР)
# 20660                            ОсОО "Же Кан" (ИУ-Китай)
# 23015                                 ОсОО "ЖИАН" (ИУ КНР
# 27700                  ОсОО "Rui Shin" (Жуй Щин) (ИУ-КНР)
# 33350                             ОсОО "ГОСИН" (ИУ-Китай)
# 34142                            ОсОО "Карнавал" (ИУ-КНР)
# 35004                  ОсОО "Текин Инвестмент" (ИУ-Китай)
# 35075                            ОсОО "Хуалон" (ИУ-Китай)
# 36415                           ОсОО "Чжаньцзян" (ИУ-КНР)
# 37749   Общество с ограниченной ответственностью "YITO...
# 40903   ОсОО "Научно-коммерческая фирма "Хын-Тай" (ИУ-...
# 42374   ОсОО "NICHIMEN INTERNATIONAL L.L.C." (" НИЧИМЕ...
# 47787        ОсОО "ЗРИ ФРЕНДС" "THREE FRIENDS" (ИУ-Китай)
# 49566                               ОсОО "Джунхай-Дордой"
# 52651         Иностранное Китайское ОсОО "Шин Кен" Ак Суу
# 54571   Общество с ограниченной ответственностью «Ай-и...
# 55385   Общество с ограниченной ответственностью «Кырг...
# 64167   Общество с ограниченной ответственностью "Байс...
# 71484   Общество с ограниченной ответственностью "Гуд ...
# 72373   Общество с ограниченной ответственностью "Горн...
# 76595   Общество с ограниченной ответственностью "Чи Гун"
# 76962      Общественный фонд "Корейский культурный центр"
# 77121   Общество с ограниченной ответственностью "Бирж...
# 78608   Объединение юридических лиц (ассоциация, союз)...
# 79098   Филиал Компании с ограниченной ответственность...
# 79175   Общество с ограниченной ответственностью "Цент...
# 79664   Общество с ограниченной ответственностью "Кунл...
# 79766   Общество с ограниченной ответственностью "Лайн...
# 80643   Общество с ограниченной ответственностью "АССЕ...
# 84498   Общество с ограниченной ответственностью "Цент...
# 84531   Общество с ограниченной ответственностью "Ийги...
# 84612   Общество с ограниченной ответственностью "Като...
# 87594   Общество с ограниченной ответственностью "Бора...
# 88449   Открытое акционерное общество "Страховая компа...
# 93860   Объединение юридических лиц "Аассоциация предп...
# 97707   Общество с ограниченной ответственностью "Упра...
# 102978  Общество с ограниченной ответственностью "Горн...
# 103716  Общество с ограниченной ответственностью "Горн...
# 105970  Общество с ограниченной ответственностью "Гоин...
# 108627  Общество с ограниченной ответственностью "Стал...
# 109239  Общество с ограниченной ответственностью "AI_T...
# 111676  Общество с ограниченной ответственностью "Oasi...
# 117534  Общество с ограниченной ответственностью "Brig...
# 120519  Общество с ограниченной ответственностью "Zhon...
# 124521  Общество с ограниченной ответственностью «Кей ...
# 125944  Общество с ограниченной ответственностью "Ай-Ч...
#
#                             director  \
# 349                         Цзинь Юй
# 1867                     Чен Юуй Чын
# 2074                         Юй Фань
# 2528    Омуралиева Айя Абдыхалиловна
# 3713                       Ма Яо Тин
# 5695                      Юй Сяоцзин
# 6327                       Яу Гаомин
# 7385                          Чен Иа
# 9571                           Ма Яо
# 10641                        Яо Жиан
# 11844                     Ван Фан Яо
# 16756                         Ай Лу
# 17359                       Ли Ли йу
# 20245                      йу йиминг
# 20660                  Йе Фень Гуань
# 23015                         Чен Иа
# 27700                     лю цзун юй
# 33350                   Ию Джан Жиан
# 34142                     Юй Шаодзюн
# 35004                    Яо Миньчань
# 35075                     Чэн Лон Ие
# 36415                   юй чжаньцзян
# 37749                          Юй Юе
# 40903                       Июе Минь
# 42374                        Юи Линь
# 47787                    Юй  Хуэйинь
# 49566                      Щу Юй Чун
# 52651                        Сао Иео
# 54571                       Ай Айхан
# 55385                      Йе Жинсун
# 64167           Мейкин кызы Ай Керим
# 71484                      Хэ Чен Юй
# 72373                    Юе Цзяньцин
# 76595                     Яо Мэйжунг
# 76962                    Хан Санг Ый
# 77121                       Юэ Хэ Фу
# 78608                       Юэ Хэ Фу
# 79098                        Лэй Июй
# 79175                       Юэ Хэ Фу
# 79664                    Юу Джинфенг
# 79766                     Жен Мин Юе
# 80643                          Юй Бо
# 84498                        Юе Хефу
# 84531                        Юе Хефу
# 84612                    Яо Цзюньвэй
# 87594                      Яо Мэйжун
# 88449                    Юй Хайцзун
# 93860                      Хэ Чен Юй
# 97707                   Чюай Джун Йи
# 102978                          Ю Яо
# 103716                          Ю Яо
# 105970                     Хэ Чен Юй
# 108627                     Ши Юе Мин
# 109239               Ай Халилибрахим
# 111676                 Джонг Сонг Ай
# 117534                       Хуан Юй
# 120519                    Юй Шанлинь
# 124521                  Джунг Янг Ей
# 125944                        Ай Мин
#
#                                                  activity  \
# 349
# 1867
# 2074
# 2528                   Управление социальными программами
# 3713              Прочая деятельность по охране здоровья.
# 5695         Разработка месторождений полезных ископаемых
# 6327               Добыча камня для строительства 14.11.0
# 7385                                  Разведочное бурение
# 9571    Выращивание зерновых и зернобобовых культур, в...
# 10641
# 11844
# 16756
# 17359
# 20245
# 20660
# 23015
# 27700
# 33350
# 34142
# 35004
# 35075
# 36415
# 37749   Оптовая торговля автомобилями и легкими автотр...
# 40903
# 42374
# 47787
# 49566
# 52651
# 54571                Строительство жилых и нежилых зданий
# 55385   Производство различных химических продуктов, н...
# 64167   оптовая торговля широким ассортиментом товаров...
# 71484   Оптовая  торговля прочим топливом, смазочными ...
# 72373   Добыча и обогащение руд драгоценных (благородн...
# 76595                 Деятельность в области стоматологии
# 76962   Деятельность прочих общественных организаций, ...
# 77121               Оптовая неспециализированная торговля
# 78608   Деятельность прочих общественных организаций, ...
# 79098                        Строительство железных дорог
# 79175               Оптовая неспециализированная торговля
# 79664                    Предоставление услуг гостиницами
# 79766   Добыча и обогащение руд драгоценных (благородн...
# 80643                    Управление недвижимым имуществом
# 84498                        Деятельность в области права
# 84531                Строительство жилых и нежилых зданий
# 84612                         Письменный и устный перевод
# 87594               Оптовая неспециализированная торговля
# 88449   Прочая вспомогательная деятельность в сфере фи...
# 93860   Деятельность прочих общественных организаций, ...
# 97707                               Добыча гравия и песка
# 102978   Добыча прочих природных минералов и горных пород
# 103716   Добыча прочих природных минералов и горных пород
# 105970               Строительство жилых и нежилых зданий
# 108627  Производство строительных металлических констр...
# 109239               Строительство жилых и нежилых зданий
# 111676      Растениеводство в сочетании с животноводством
# 117534  Бурение скважин для добычи нефти и природного ...
# 120519  Производство очищенных нефтепродуктов, в том ч...
# 124521      Прочая деятельность в области здравоохранения
# 125944  Производство хлеба и мучных кондитерских издел...
#
#                                                  founders
# 349     Международная торговая Компания " Залив, Ассоц...
# 1867                         Корпорация  внешней торговли
# 2074    МП "МБМ" директор Асосков Ю.В., Синьзянская ме...
# 2528    Абдылдабекова Айя, Норузбаева Кишимжан, Абдрах...
# 3713                                            Ма Яо Тин
# 5695    Компания с ограниченной ответственностью "DT M...
# 6327                  Чжао Оксана Владимировна, Яу Гаомин
# 7385    Общество с ограниченной ответственностью "Wond...
# 9571                                                Ма Яо
# 10641                                             Яо Жиан
# 11844                                          Ван Фан Яо
# 16756                                              Ай Лу
# 17359                                            Ли Ли Йу
# 20245
# 20660
# 23015                                              Чен Иа
# 27700
# 33350                                        Ию Джан Жиан
# 34142                                          Юй Шаодзюн
# 35004                                         Яо Миньчань
# 35075                                          Чэн Лон Ие
# 36415
# 37749                                               Юй Юе
# 40903                                           Ванг Фуде
# 42374                                             Юи Линь
# 47787                      Пэй Дэю, Юй Хуэйинь, Ли Го Щин
# 49566                                 Лю Фуцан, Щу Юй Чун
# 52651                                             Сао Иео
# 54571   Ай Айхан, Джазаева Лейли Супаймановна, Ай Хали...
# 55385                                           Йе Жинсун
# 64167                                Мейкин кызы Ай Керим
# 71484              Хэ Чен Юй, Жумалиев Элнур Самарбекович
# 72373                  Ли Цяосин, Цзэн Шунго, Юе Цзяньцин
# 76595                                          Яо Мэйжунг
# 76962                                         Хан Санг Ый
# 77121   Юэ Хэ Фу, Общество с ограниченной ответственно...
# 78608   ОсОО "Эгиз-Суу", ОсОО "Централ Эйжа Интернэшнл...
# 79098   Компания с ограниченной ответственностью "Кита...
# 79175                                            Юэ Хэ Фу
# 79664                              Юу Джинфенг, Ли Чуньфу
# 79766                                          Жен Мин Юе
# 80643   Танг Фангчун, Общество с ограниченной ответств...
# 84498                                             Юе Хефу
# 84531                                             Юе Хефу
# 84612                                         Яо Цзюньвэй
# 87594                                           Яо Мэйжун
# 88449                Юй Хайцзун, Джоу Айцзун, Ман Чун Сяо
# 93860   Общество с ограниченной ответственностью "Динь...
# 97707                                        Чюай Джун Йи
# 102978                                               Ю Яо
# 103716                                               Ю Яо
# 105970  Хэ Чен Юй, Садыков Чынгыз Самарбекович, Орозба...
# 108627                                          Ши Юе Мин
# 109239                                    Ай Халилибрахим
# 111676  Бакнер Дэвид Вейн, Частная Компания с ограниче...
# 117534                                 Цзие Энси, Хуан Юй
# 120519  Общество с ограниченной ответственностью "Сред...
# 124521  Тыналиева Гулжан Шайкидиновна, Джунг Янг Ей, П...
# 125944                                  Ай Мин, Юй Хайтао

# %%
child_regex('Жээнбеков', 'Сооронбай')
# Out:
# re.compile(r'Жээнбекова?\s+\w+\s+Сооронб|\w+\s+Сооронб\w+\s+Жээнбеков',
# re.IGNORECASE|re.UNICODE)
